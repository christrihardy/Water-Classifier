# %% [markdown]
# ### **1. Libraries**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import src.util as utils
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### **2. Load Config File**

# %%
config = utils.load_config()

# %% [markdown]
# ### **3. Load Train set**

# %%
x_train = utils.pickle_load(config["train_set_path"][0])
y_train = utils.pickle_load(config["train_set_path"][1])

# %%
# concat input-output
train_set = pd.concat([x_train, y_train], axis = 1)

# %% [markdown]
# ### **4. Data Exploration**

# %% [markdown]
# 4.1. Quick Look Dataset

# %%
# Quick take a loof to our train data
train_set
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2018  7.031684  237.083948  35434.280062     7.617649  381.337527
# 2740  6.789821  197.300014  22527.681207     5.166942  399.981755
# 2746  5.636924  159.139410  27283.780655     6.918727  328.907287
# 1468  6.279842  175.890640  11582.505249     7.059985  333.076588
# 1417  6.703487  182.129514  24316.875146     7.009806  341.333952
# ...        ...         ...           ...          ...         ...
# 101   7.348845  223.264940  11519.046527     8.889559  333.076588
# 1734  3.928556  191.665998  17328.161457     7.692417  306.479558
# 394   8.736371  194.677687  24283.658791     8.855544  329.004205
# 2242  6.645657  170.269715  23432.109730     7.066565  333.076588
# 2846  7.222998  179.560290  21314.869789     5.864717  333.076588
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2018    365.032503       13.453872        33.439868   3.825937           1
# 2740    422.482029       15.916605        47.935105   4.512068           1
# 2746    317.830981       13.611408        36.335199   3.007138           1
# 1468    430.322092       15.674785        86.760257   3.278584           0
# 1417    479.537497       20.088643        53.925045   4.223884           0
# ...            ...             ...              ...        ...         ...
# 101     494.158434       18.145374        73.715522   4.880875           0
# 1734    406.085614        9.578602        45.480738   5.060836           0
# 394     333.623794       16.516232        67.250473   3.802116           1
# 2242    513.364946       20.264678        78.900888   4.170658           0
# 2846    435.573888       11.878370        79.394008   3.966259           1
#
# [2293 rows x 10 columns]

# %%
train_set.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2293.000000  2293.000000   2293.000000  2293.000000  2293.000000
# mean      7.084083   196.721382  21814.370079     7.097090   333.822546
# std       1.469150    32.636122   8788.242153     1.605328    36.421918
# min       0.227499    47.432000    320.942611     1.683993   129.000000
# 25%       6.280905   177.213792  15379.912763     6.110019   317.279123
# 50%       7.031684   197.331291  20791.318981     7.106043   333.076588
# 75%       7.869782   216.551887  27025.206963     8.098312   350.448584
# max      13.541240   323.124000  61227.196008    13.043806   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2293.000000     2293.000000      2293.000000  2293.000000  2293.000000
# mean     427.993678       14.263934        66.117454     3.970863     0.390318
# std       81.152396        3.269456        15.782893     0.782183     0.487928
# min      181.483754        4.371899         0.738000     1.492207     0.000000
# 25%      367.044379       12.065963        56.347689     3.437946     0.000000
# 50%      424.666112       14.176501        66.542198     3.959294     0.000000
# 75%      485.098483       16.482835        76.290285     4.494544     1.000000
# max      708.226364       27.006707       124.000000     6.739000     1.000000

# %% [markdown]
# 4.2. Label Distribution

# %%
# Check distribution of our label data
ax = sns.countplot(data = train_set, x = "Potability", label = train_set["Potability"].unique())
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1398'), Text(0, 0, '895')]

# %% [markdown]
# Balance data

# %%
# balance data with smote
x, y = SMOTE(sampling_strategy = "minority",
            random_state = 123).fit_resample(x_train, y_train)
train_set_bal = pd.concat([x, y], axis = 1)

# %%
# Check balancing result
y.value_counts()
# Out:
# 1    1398
# 0    1398
# Name: Potability, dtype: int64

# %%
# Check the balanced data with smote method
ax = sns.countplot(data = train_set_bal, x = "Potability", label = train_set_bal["Potability"].unique())
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1398'), Text(0, 0, '1398')]

# %% [markdown]
# 4.3. PH distribution

# %%
# Check distribution of ph
sns.kdeplot(data = train_set_bal, x = "ph", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Density'>

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2293 entries, 2018 to 2846
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2293 non-null   float64
#  1   Hardness         2293 non-null   float64
#  2   Solids           2293 non-null   float64
#  3   Chloramines      2293 non-null   float64
#  4   Sulfate          2293 non-null   float64
#  5   Conductivity     2293 non-null   float64
#  6   Organic_carbon   2293 non-null   float64
#  7   Trihalomethanes  2293 non-null   float64
#  8   Turbidity        2293 non-null   float64
#  9   Potability       2293 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 197.1 KB

# %% [markdown]
# 4.4. Hardness Distribution

# %%
# Check distribution of hardness
sns.kdeplot(data = train_set_bal, x = "Hardness", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Density'>

# %% [markdown]
# 4.5. Solids Distribution

# %%
# Check distribution of solids
sns.kdeplot(data = train_set_bal, x = "Solids", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Solids', ylabel='Density'>

# %% [markdown]
# 4.6. Chloramines Distribution

# %%
# Check distribution of chloramines
sns.kdeplot(data = train_set_bal, x = "Chloramines", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Chloramines', ylabel='Density'>

# %% [markdown]
# 4.7. Sulfate Distribution

# %%
# Check distribution of sulfate
sns.kdeplot(data = train_set_bal, x = "Sulfate", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Sulfate', ylabel='Density'>

# %% [markdown]
# 4.8. Conductivity Distribution

# %%
# Check distribution of Conductivity
sns.kdeplot(data = train_set_bal, x = "Sulfate", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Sulfate', ylabel='Density'>

# %% [markdown]
# 4.9. Organic Carbon Distribution

# %%
# Check distribution of organic carbon
sns.kdeplot(data = train_set_bal, x = "Organic_carbon", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Organic_carbon', ylabel='Density'>

# %% [markdown]
# 4.10. Trihalomethanes Distribution

# %%
# Check distribution of trihalomethanes
sns.kdeplot(data = train_set_bal, x = "Trihalomethanes", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Trihalomethanes', ylabel='Density'>

# %% [markdown]
# 4.11. Turbidity Distribution

# %%
# Check distribution of turbidity
sns.kdeplot(data = train_set_bal, x = "Turbidity", hue = "Potability")
# Out:
# <AxesSubplot:xlabel='Turbidity', ylabel='Density'>

# %% [markdown]
# 4.12. Correlation Heatmap

# %%
# Correlation heatmap
plt.figure(figsize = (7,6))
sns.heatmap(train_set_bal.corr(), fmt= ".2f", annot= True,square= True)
plt.show()

# %% [markdown]
# We can see that the predictors have very weak correlation with the target (Potability)
